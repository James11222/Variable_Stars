# %%
import PIPS as PIPS
from PIPS import OC
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 22
plt.style.use("dark_background")

### Text Color ###
for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '1.0'  # white (value goes from 0 to 1)
    
### Figure Color ###
for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#000630'  # Hex Color Code for Background Color
colors = [
    '#08F7FE',  # teal/cyan
    '#FE53BB',  # pink
    '#F5D300',  # yellow
    '#00ff41',  # matrix green
]

PIPS.about()
# Out:
# --------------------------
# -    Welcome to PIPS!    -
# --------------------------
# Version: 0.3.0-alpha.6
# Authors: Y. Murakami, A. Savel, J. Sunseri, A. Hoffman
# --------------------------
# Download the latest version from: https://pypi.org/project/astroPIPS
# Report issues to: https://github.com/SterlingYM/astroPIPS
# Read the documentations at: https://PIPS.readthedocs.io
# --------------------------

# %% [markdown]
# # Import Old Period Data from Jurscik 2011

# %%
col_names = ['star_num', 'm_star', 'mean_period', 'JD0', 'JD1', 'mean HJD', 'N', 'O-C', 'O-C err']
df = pd.read_csv("Jurcsik_OC.tsv", sep='\t', skiprows=50, names = col_names)

# %%
df #Note, we use vizier for AAS data but for paper use Jurscik_Supplemental_Data
# Out:
#       star_num m_star  mean_period      JD0      JD1   mean HJD    N     O-C  \
# 0            1            0.520613  13372.5  14079.7  2413804.0   16 -0.2474
# 1            1            0.520613  14437.5  15161.9  2415044.7   32 -0.1843
# 2            1            0.520613  22455.4  22840.6  2422750.7  131  0.0764
# 3            1            0.520613  23858.5  24684.9  2424470.8  157  0.1268
# 4            1            0.520613  28963.4  30078.6  2429736.9   31  0.2083
# ...        ...    ...          ...      ...      ...        ...  ...     ...
# 2122       203            0.289795  47276.3  47555.6  2447519.5   48  0.0058
# 2123       203            0.289795  48755.6  49092.0  2448939.1  181  0.0001
# 2124       203            0.289795  50162.4  50176.8  2450170.9  168  0.0023
# 2125       203            0.289795  50622.7  51288.0  2451036.5  159 -0.0034
# 2126       203            0.289795  54872.4  54965.5  2454931.9  575 -0.0117
#
#       O-C err
# 0      0.0128
# ...

# %%
dataFrame_list = []
for i in range(1,max(df['star_num']) + 1):
    if len(df[df['star_num'] == i]) == 0:
        df_Vi = 'there is no O-C data for this star'
        dataFrame_list.append(df_Vi)
    else:
        df_Vi = df[df['star_num'] == i]
        dataFrame_list.append(df_Vi)


#Note, index of data list is offset to V___ number by 1
print("\n\n\n An example with OC Data")    
print(dataFrame_list[8])
print("\n\n\n")       

print("\n\n\n An example with no OC Data")    
print(dataFrame_list[4])
# Out:
#  An example with OC Data
#     star_num m_star  mean_period      JD0      JD1   mean HJD    N     O-C  \
# 59         9             0.54156  13372.5  14079.7  2413804.0   16 -0.0874
# 60         9             0.54156  14437.5  15161.9  2415042.1   34 -0.0538
# 61         9             0.54156  19479.8  20656.9  2420274.0   25  0.0283
# 62         9             0.54156  22729.5  22840.6  2422752.9  131  0.0562
# 63         9             0.54156  23858.5  24684.9  2424529.4  243  0.0630
# 64         9             0.54156  28963.4  30078.6  2429510.0   77  0.0888
# 65         9             0.54156  31965.7  32700.8  2432164.8   38  0.0936
# 66         9             0.54156  33390.4  33763.6  2433496.7   43  0.0958
# 67         9             0.54156  34076.5  34834.5  2434319.5   97  0.0905
# 68         9             0.54156  35219.3  35933.7  2435569.7  142  0.0913
# 69         9             0.54156  36367.3  37131.4  2436777.2  101  0.0918
# ...

# %%
dataFrame_list[5]
# Out:
#     star_num m_star  mean_period      JD0      JD1   mean HJD    N     O-C  \
# 33         6            0.514327  13372.5  14079.7  2413804.0   16  0.0790
# 34         6            0.514327  14437.5  15161.9  2415042.1   34  0.0659
# 35         6            0.514327  22455.4  22840.6  2422751.0  132 -0.0223
# 36         6            0.514327  23858.5  24684.9  2424525.9  198 -0.0411
# 37         6            0.514327  28963.4  30078.6  2429713.6   32 -0.0769
# 38         6            0.514327  33034.5  33763.6  2433487.8   43 -0.0922
# 39         6            0.514327  34118.3  34834.5  2434335.5   92 -0.0858
# 40         6            0.514327  35219.3  35933.6  2435565.7  133 -0.0846
# 41         6            0.514327  36367.3  37131.4  2436772.9   98 -0.0779
# 42         6            0.514327  37757.5  38502.7  2438115.9   24 -0.0769
# 43         6            0.514327  42838.5  43254.6  2443044.1   59 -0.0491
# ...

# %%
list(dataFrame_list[2]['mean_period'])[0]
# Out:
# 0.558204

# %% [markdown]
# # Create OC Diagram

# %%
# p_ref = 0.54156 # Mean Reference Period 
# O_ref = 13804.0 # Original Reference Observation Time in MJD
# O_list = [59315.79742888528] #Observation Time in MJD 

# OC_list = []
# N_list = []
# for O in O_list:
#     N = np.round((O - O_ref)/p_ref) 
#     C = N * p_ref + O_ref
#     OC = O-C
#     N_list.append(N)
#     OC_list.append(OC)
    
# plt.scatter(N_list, OC_list)

# %%
# data = pd.read_csv('mnras0419-2173-SD1.txt',delim_whitespace=True)
# data.head()

# %%
# # the target star
# name = 'V006'
# band = 'V'
# LPP_datafile = 'M3_data/m3_v6.dat'

# # cross-match Jurcsik data
# cut = (data['#star']==name) & (data['band']==band)
# x = data[cut]['HJD-2400000'].to_numpy()
# y = data[cut]['mag'].to_numpy()
# yerr = 0.01 * np.ones_like(y)

# # initialize PIPS photdata
# star_J11 = PIPS.photdata([x,y,yerr])
# star_KAIT = PIPS.photdata(PIPS.data_readin_LPP(LPP_datafile,filter=band))
# star_KAIT.cut(yerr_max=0.05)

# %%
# # initialize OC object
# oc = OC.longdata([star_J11,star_KAIT]) # takes in a list of photdata

# # run OC! (takes in **kwargs for star.get_period(**kwargs))
# oc.run_OC(p_min=0.3,p_max=0.9)

# %%
# # results
# print(oc.oc)      # O-C values
# print(oc.oc_err)  # O-C uncertainties
# print(oc.x_means) # mean x-values
# print(oc.p_ref)   # 'mean' period

# print(oc.oc[1]-oc.oc[0]) 
# # this is the OC-value offset between Jurcsik and KAIT!
# # (simply add this to Jurcsik's O-C value to get ours in the same frame)

# %%
names_list = ['V001', 'V003', 'V005','V006', 'V007', 'V008', 'V009','V010', 'V011', 'V012']

yerr_max_list = [0,0, 0.02, 0.03, 0.03, 0.07,0, 0.05,0,0.05]




jurcsik = pd.read_csv('jurcsik.txt',delim_whitespace=True)
jurcsik.head()
corwin  = pd.read_csv('corwin.txt',delim_whitespace=True,skiprows=13)
corwin.head()
# Out:
#   name           JD filter     mag
# 0   v1  2448755.668      B  16.364
# 1   v1  2448755.683      B  16.429
# 2   v1  2448755.698      B  16.394
# 3   v1  2448755.714      B  16.162
# 4   v1  2448755.751      B  14.961

# %% [markdown]
# # V001 OC Diagram

# %%
name = names_list[0] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[0] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v1' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[0] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
# yerr_max_ = yerr_max_list[i]
# star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[0]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[0]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#
OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[0]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#

# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref


print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# ...
# O-C: [-0.0893, 0.2034, -0.028]
# err: [0.0006, 0.0002, 0.0022]
# MJD: [48984.9, 54929.0, 59310.4]
# p_ref: 0.520613
# Jurcsik - Corwin: -0.22790
# KAIT - Jurcsik: -0.23145
# the MJD is 59310.44470973 and the O-C Value is -0.45854917 +/- 0.00209829

# %%
x_data = np.array((dataFrame_list[0]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[0]['O-C'][:]))
y_data_err = np.array((dataFrame_list[0]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VOO1.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V003 OC Diagram

# %%
name = names_list[1] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[1] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v3' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[1] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
# yerr_max_ = yerr_max_list[i]
# star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[2]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[2]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#
OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[2]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#

# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref


print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# ...
# O-C: [-0.0155, 0.0383, -0.0468]
# err: [0.0052, 0.0009, 0.0048]
# MJD: [48984.9, 54931.4, 59310.4]
# p_ref: 0.558204
# Jurcsik - Corwin: 0.05383
# KAIT - Jurcsik: -0.08510
# the MJD is 59310.44470973 and the O-C Value is -0.16249570 +/- 0.00399152

# %%
x_data = np.array((dataFrame_list[2]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[2]['O-C'][:]))
y_data_err = np.array((dataFrame_list[2]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VOO3.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V006 OC Diagram

# %%
name = names_list[3] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[3] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v6' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[3] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
yerr_max_ = yerr_max_list[3]
star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[5]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[5]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#

if OC_VALUE > oc.p_ref/2:
    OC_VALUE -= oc.p_ref
elif OC_VALUE < -oc.p_ref/2:
    OC_VALUE += oc.p_ref
    
OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[5]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# O-C: [-0.1484, -0.0656, 0.0202]
# err: [0.0003, 0.0002, 0.0012]
# MJD: [48984.9, 54929.3, 59330.3]
# p_ref: 0.514327
# Jurcsik - Corwin: 0.08283
# KAIT - Jurcsik: 0.08576
# the MJD is 59330.32483581 and the O-C Value is 0.16806207 +/- 0.00108680

# %%
x_data = np.array((dataFrame_list[5]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[5]['O-C'][:]))
y_data_err = np.array((dataFrame_list[5]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VOO6.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V007 OC Diagram

# %%
name = names_list[4] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[4] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v7' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[4] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
yerr_max_ = yerr_max_list[4]
star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[6]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[6]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#
OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[6]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))



# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref
# Out:
# ...
# O-C: [-0.0422, -0.0072, 0.0269]
# err: [0.0033, 0.0016, 0.0012]
# MJD: [48984.9, 54938.1, 59319.3]
# p_ref: 0.497428
# Jurcsik - Corwin: 0.03505
# KAIT - Jurcsik: 0.03410
# the MJD is 59319.32376833 and the O-C Value is 0.00639921 +/- 0.00092233

# %%
x_data = np.array((dataFrame_list[6]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[6]['O-C'][:]))
y_data_err = np.array((dataFrame_list[6]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')

# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VOO7.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V009 OC Diagram

# %%
name = names_list[6] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[6] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v9' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[6] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
# yerr_max_ = yerr_max_list[i]
# star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[8]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[8]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#
OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[8]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))




# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref
# Out:
# ...
# O-C: [0.1565, 0.0872, 0.0403]
# err: [0.0003, 0.0001, 0.0007]
# MJD: [48984.9, 54929.2, 59320.1]
# p_ref: 0.541560
# Jurcsik - Corwin: -0.06925
# KAIT - Jurcsik: -0.04686
# the MJD is 59320.10889937 and the O-C Value is -0.11546422 +/- 0.00071320

# %%
x_data = np.array((dataFrame_list[8]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[8]['O-C'][:]))
y_data_err = np.array((dataFrame_list[8]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')



# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VOO9.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V010 OC Diagram

# %%
name = names_list[7] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[7] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v10' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[7] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
yerr_max_ = yerr_max_list[7]
star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[9]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[9]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#

# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref

OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[9]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# ...
# O-C: [-0.1905, 0.0015, -0.0472]
# err: [0.0004, 0.0002, 0.0047]
# MJD: [48984.9, 54928.5, 59321.9]
# p_ref: 0.569529
# Jurcsik - Corwin: 0.19199
# KAIT - Jurcsik: -0.04873
# the MJD is 59321.89080645 and the O-C Value is 0.14456992 +/- 0.00452657

# %%
x_data = np.array((dataFrame_list[9]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[9]['O-C'][:]))
y_data_err = np.array((dataFrame_list[9]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VO10.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V011 OC Diagram

# %%
name = names_list[8] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[8] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v11' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[8] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
# yerr_max_ = yerr_max_list[i]
# star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[10]['mean_period'])[0],template_idx=0,Nterms=7,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[10]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#

# if OC_VALUE > oc.p_ref/2:
#     OC_VALUE -= oc.p_ref
# elif OC_VALUE < -oc.p_ref/2:
#     OC_VALUE += oc.p_ref

OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[10]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# ...
# O-C: [0.0008, -0.0022, -0.0054]
# err: [0.0002, 0.0002, 0.0007]
# MJD: [48984.9, 54928.9, 59311.3]
# p_ref: 0.507892
# Jurcsik - Corwin: -0.00303
# KAIT - Jurcsik: -0.00320
# the MJD is 59311.32406062 and the O-C Value is -0.00760399 +/- 0.00069794

# %%
x_data = np.array((dataFrame_list[10]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[10]['O-C'][:]))
y_data_err = np.array((dataFrame_list[10]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VO11.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# # V012 OC Diagram

# %%
name = names_list[9] #--------------CHANGE HERE--------------#
band = 'V'
LPP_datafile = 'M3_data/m3_' + names_list[9] + '.dat' #--------------CHANGE HERE--------------#

#-------------
# Corwin data
#-------------
corwin_name = 'v12' #--------------CHANGE HERE--------------#

cut = (corwin['name']==corwin_name) & (corwin['filter']==band)
x = corwin[cut]['JD'].to_numpy() - 2400000
y = corwin[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_C01 = PIPS.photdata([x,y,yerr],label='Corwin')

#--------------
# Jurcsik data
#--------------
jurcsik_name = names_list[9] #--------------CHANGE HERE--------------#

cut = (jurcsik['#star']==jurcsik_name) & (jurcsik['band']==band)
x = jurcsik[cut]['HJD-2400000'].to_numpy()
y = jurcsik[cut]['mag'].to_numpy()
yerr = 0.01 * np.ones_like(y)
star_J11 = PIPS.photdata([x,y,yerr],label='Jurcsik')

#--------------------------
# initialize PIPS photdata
#--------------------------
data = PIPS.data_readin_LPP(LPP_datafile,filter=band)
star_KAIT = PIPS.photdata(data,label='KAIT')
yerr_max_ = yerr_max_list[9]
star_KAIT.cut(yerr_max=yerr_max_)

#--------------------------
# initialize OC object
#--------------------------
photdata_list = [star_C01,star_J11,star_KAIT]
oc = OC.longdata(photdata_list)

#--------------------------
# run OC! (takes in **kwargs for star.get_period(**kwargs))
#--------------------------
oc.run_OC(p_ref=list(dataFrame_list[11]['mean_period'])[0],template_idx=0,Nterms=5,p_min=0.2,p_max=0.9)

#--------------CHANGE HERE--------------#

#Nterms = 7 for RRab, Nterms = 5 for RRc stars
#We set template_idx to be 0 so Corwin is the reference template

#-------------
# results
#-------------
# outputs
print('O-C:',[float(f'{val:.4f}') for val in oc.oc])      # O-C values
print('err:',[float(f'{val:.4f}') for val in oc.oc_err])  # O-C uncertainties
print('MJD:',[float(f'{val:.1f}') for val in oc.x_means]) # mean x-values
print(f'p_ref: {oc.p_ref:.6f}')   # 'mean' period

# check:
# this value should agree with the offset in O-C values 
# between Jurcsik and Corwin.

# correct for rounding ('round','floor','ceil',etc.)
offset_JC = oc.oc[1]-oc.oc[0]
if offset_JC > oc.p_ref/2:
    offset_JC -= oc.p_ref
elif offset_JC < -oc.p_ref/2:
    offset_JC += oc.p_ref
    
print(f'Jurcsik - Corwin: {offset_JC:.5f}')

# the result:
# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
print(f'KAIT - Jurcsik: {oc.oc[2]-oc.oc[1]:.5f}') 

# correct for rounding ('round','floor','ceil',etc.)
offset_KAIT = oc.oc[2]-oc.oc[1]
if offset_KAIT > oc.p_ref/2:
    offset_KAIT -= oc.p_ref
elif offset_KAIT < -oc.p_ref/2:
    offset_KAIT += oc.p_ref

# this is the OC-value offset between Jurcsik and KAIT!
# (simply add this to Jurcsik's O-C value to get ours in the same frame)
OC_VALUE = list(dataFrame_list[11]['O-C'][:])[-1] + offset_KAIT #--------------CHANGE HERE--------------#

if OC_VALUE > oc.p_ref/2:
    OC_VALUE -= oc.p_ref
elif OC_VALUE < -oc.p_ref/2:
    OC_VALUE += oc.p_ref

OC_err = np.sqrt((oc.oc_err[2]-oc.oc_err[1])**2 + (list(dataFrame_list[11]['O-C err'][:])[-1])**2)
#--------------CHANGE HERE--------------#



print('the MJD is {0:0.8f} and the O-C Value is {1:0.8f} +/- {2:0.8f}'.format(oc.x_means[2], OC_VALUE, OC_err))
# Out:
# ...
# O-C: [-0.0126, 0.0478, 0.0504]
# err: [0.0018, 0.0003, 0.001]
# MJD: [48984.9, 54931.6, 59320.6]
# p_ref: 0.317890
# Jurcsik - Corwin: 0.06039
# KAIT - Jurcsik: 0.00260
# the MJD is 59320.62459617 and the O-C Value is -0.25520854 +/- 0.00090696

# %%
x_data = np.array((dataFrame_list[11]['mean HJD'][:])) - 2400000
y_data = np.array((dataFrame_list[11]['O-C'][:]))
y_data_err = np.array((dataFrame_list[11]['O-C err'][:]))
x_, y_, y_err  = oc.x_means[2], OC_VALUE, OC_err
 

x_data = np.append(x_data,x_)
y_data = np.append(y_data,y_)
y_data_err = np.append(y_data_err, y_err)

df_ = pd.DataFrame({'MJD':x_data,'O-C':y_data,'O-C err':y_data_err})
df_.to_csv(jurcsik_name + '.csv')


# #Pretty Plot
# plt.figure(figsize=(8,4))
# ax = plt.gca()
# plt.title(jurcsik_name)
# plt.xlabel("MJD")
# plt.ylabel("O-C")

# # Redraw the data with low alpha and slighty increased linewidth:
# n_shades = 10
# diff_linewidth = 1.05
# alpha_value = 0.3 / n_shades
# for n in range(1, n_shades+1):
#     if n == n_shades:
#         plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='red')
        
#     plt.scatter(x_data,y_data,marker='o',
#             linewidth=1+(diff_linewidth*n),
#             alpha=alpha_value,
#             color='white')
# plt.errorbar(x_data,y_data,y_data_err,color='white', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# plt.errorbar(x_,y_,y_err,color='red', fmt='o', ms=6, ecolor='limegreen', capsize=4)
# #plt.scatter(x_,y_,color='red', marker='o')
# #plt.grid()
# #plt.savefig('OC_VO12.png', format='png', dpi=300, bbox_inches='tight')
# plt.show()
